# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# # CLASE 1: Repaso Inicial - Lenguaje de programación Python
# Fecha: 18/04/2024

# %% [markdown]
# # EJERCICIOS 1

# %% [markdown]
# ## Ejecución de código

# %% [markdown]
# 1 - Crea un programa de Python que imprima tu nombre

# %%
x = 'Charles'
print('Mi nombre es',x)
# Out:
# Mi nombre es Charles

# %% [markdown]
# 2 - Crea un programa de Python que imprima tu nombre, tu edad y cuántos hermanos tienes

# %% [markdown]
# Algunas maneras de realizarlo

# %%
x = 'Charles'
y = 34
z = 1
print('Mi nombre es', x,'mi edad es', y, 'y tengo', z, 'hermano')
# Out:
# Mi nombre es Charles mi edad es 34 y tengo 1 hermano

# %%
print('Mi nombre es {}, mi edad es {} y tengo {} hermano.'.format(x, y, z))
# Out:
# Mi nombre es Charles, mi edad es 34 y tengo 1 hermano.

# %% [markdown]
# ## Tipos de Datos

# %% [markdown]
# 3 - ¿ Qué tipo de datos es x= 1.245?

# %%
x = 1.245
type(x)
# Out:
# float

# %% [markdown]
# 4 - ¿ Qué tipo de datos es x= 1?

# %%
x = 1
type(x)
# Out:
# int

# %% [markdown]
# 5 - ¿ Qué tipo de datos es x= "Hola"?

# %%
x = 'Hola'
type(x)
# Out:
# str

# %% [markdown]
# 6 - Asigna tu nombre a una variable e imprime en pantalla tu nombre y qué tipo de datos es tu nombre

# %%
x = 'Charles'
print(f"Mi nombre es {x} y el tipo de datos de x es {type(x)}")
# Out:
# Mi nombre es Charles y el tipo de datos de x es <class 'str'>

# %% [markdown]
# 7 - Convierte x = 1.3455 y y="31" a números enteros

# %%
x = 1.3455
y = '31'
print(int(x), int(y))
# Out:
# 1 31

# %% [markdown]
# 8 - Convierte x = 1 y y="31" a números decimales

# %%
x = 1
y = '31'
print(float(x), float(y))
# Out:
# 1.0 31.0

# %% [markdown]
# 9 - Convierte x = 1 y y=-1,441 a string

# %%
x = 1
y = -1.441
print(str(x), str(y))
# Out:
# 1 -1.441

# %% [markdown]
# 10 - Imprime los 3 tipos de datos numéricos más básicos que existen y da un ejemplo de cada uno

# %%
x = 2 #int
y = 3.45 #float
z = False #boolean

# %%
print(type(x), type(y), type(z))
# Out:
# <class 'int'> <class 'float'> <class 'bool'>

# %% [markdown]
# 11 - Convierte x=1.3455 a los otros 2 tipos de datos numéricos que has mencionado arriba

# %%
x = 1.3455
print(int(x), bool(x))
# Out:
# 1 True

# %% [markdown]
# ## Variables Numéricas

# %% [markdown]
# 12 - Calcula la suma de 64 + 32

# %%
x = 64 + 32
x
# Out:
# 96

# %% [markdown]
# 13 - Si x = 31.2445 y y= 1.92761, ¿cúanto es x+y?

# %%
x = 31.2445
y = 1.92761
x + y
# Out:
# 33.172109999999996

# %% [markdown]
# 14 - Calcula ahora la resta, producto y división de estos números.

# %%
print(x - y, x * y, x / y)
# Out:
# 29.316889999999997 60.227210645 16.208932304771192

# %%
print(round(x - y, 2), round(x * y, 2), round(x / y, 2))
# Out:
# 29.32 60.23 16.21

# %% [markdown]
# Nueva función round para redondear los decimales. Muy interesante.

# %% [markdown]
# 15 - Calcula el área de un cuadrado de costado 3cm

# %%
c = 3
a = c * c
a
# Out:
# 9

# %% [markdown]
# 16 - Calcula el área de una circunferencia de radio 2cm (considerar pi=3.14)

# %%
#considerar pi=3.14
pi=3.14

# %%
r = 2
a =  pi* r**2
print(a)
# Out:
# 12.56

# %% [markdown]
# 17 - Cuantos años tenías en el año 2000?

# %%
mi_edad = 34
mi_edad_2000 = 34 - (2024-2000)
mi_edad_2000
# Out:
# 10

# %% [markdown]
# 18 - Calcula el volumen de un cubo de costado 3 cm

# %%
c = 3
v = c**3
v
# Out:
# 27

# %% [markdown]
# ## Booleanos

# %% [markdown]
# 19 - Si Elena tiene 15 años y Jorge tiene 20, comprueba quien es mayor

# %%
Elena = 15
Jorge = 20
Elena > Jorge
# Out:
# False

# %% [markdown]
# 20 - Comprueba efectivamente que Elena y Jorge no tienen la misma edad

# %%
Elena == Jorge
# Out:
# False

# %% [markdown]
# ## Strings

# %% [markdown]
# 21 - ¿Cuántas letras tiene la palabra 'abecedario'?

# %%
len('abecedario')
# Out:
# 10

# %% [markdown]
# 22 - Pon en mayúscula las palabra abecedario

# %%
x = 'abecedario'
x.upper()
# Out:
# 'ABECEDARIO'

# %% [markdown]
# 23 - Limpia de espacios el siguiente texto: "  q u i e r o   a p r e n d e r   p y t h o n "

# %%
x = " q u i e r o a p r e n d e r p y t h o n "
x.replace(" ", "")
# Out:
# 'quieroaprenderpython'

# %% [markdown]
# 24 - Reemplaza el "no" por un "yo" en el siguiente texto: "no quiero aprender python, no quiero pasármelo genial!"

# %%
x = "no quiero aprender python, no quiero pasármelo genial!"
x.replace('no', 'yo')
# Out:
# 'yo quiero aprender python, yo quiero pasármelo genial!'

# %% [markdown]
# 25 - ¿Cuántas veces aparece el nombre Python en el siguiente texto?:
#
# " Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together. Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance. Python supports modules and packages, which encourages program modularity and code reuse. The Python interpreter and the extensive standard library are available in source or binary form without charge for all major platforms, and can be freely distributed.
#
# Often, programmers fall in love with Python because of the increased productivity it provides. Since there is no compilation step, the edit-test-debug cycle is incredibly fast. Debugging Python programs is easy: a bug or bad input will never cause a segmentation fault. Instead, when the interpreter discovers an error, it raises an exception. When the program doesn't catch the exception, the interpreter prints a stack trace. A source level debugger allows inspection of local and global variables, evaluation of arbitrary expressions, setting breakpoints, stepping through the code a line at a time, and so on. The debugger is written in Python itself, testifying to Python's introspective power. On the other hand, often the quickest way to debug a program is to add a few print statements to the source: the fast edit-test-debug cycle makes this simple approach very effective."

# %%
x = """ Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together. Python's simple, easy to learn syntax emphasizes readability and therefore reduces the cost of program maintenance. Python supports modules and packages, which encourages program modularity and code reuse. The Python interpreter and the extensive standard library are available in source or binary form without charge for all major platforms, and can be freely distributed.

Often, programmers fall in love with Python because of the increased productivity it provides. Since there is no compilation step, the edit-test-debug cycle is incredibly fast. Debugging Python programs is easy: a bug or bad input will never cause a segmentation fault. Instead, when the interpreter discovers an error, it raises an exception. When the program doesn't catch the exception, the interpreter prints a stack trace. A source level debugger allows inspection of local and global variables, evaluation of arbitrary expressions, setting breakpoints, stepping through the code a line at a time, and so on. The debugger is written in Python itself, testifying to Python's introspective power. On the other hand, often the quickest way to debug a program is to add a few print statements to the source: the fast edit-test-debug cycle makes this simple approach very effective."""

# %%
x.count('Python')
# Out:
# 8

# %% [markdown]
# 26 - Pon en mayúscula la primera letra de cada palabra de la siguiente frase:
#
# "python is an interpreted, object-oriented, high-level programming language with dynamic semantics. its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together."

# %%
x = "python is an interpreted, object-oriented, high-level programming language with dynamic semantics. its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together."

# %%
x.title()
# Out:
# 'Python Is An Interpreted, Object-Oriented, High-Level Programming Language With Dynamic Semantics. Its High-Level Built In Data Structures, Combined With Dynamic Typing And Dynamic Binding, Make It Very Attractive For Rapid Application Development, As Well As For Use As A Scripting Or Glue Language To Connect Existing Components Together.'
